# %%
import pandas as pd
# %config Completer.use_jedi = False

# %%
bigmac = pd.read_csv("./pandasfiles/bigmac.csv",parse_dates=["Date"])
bigmac.head(3)
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    datetime64[ns]
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 15.4+ KB

# %%
bigmac.set_index(keys = ["Date","Country"],inplace=True)

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac.sort_index(inplace=True)

# %%
bigmac.index
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[10]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Denmark')

# %% [markdown]
#  ### Extract Index Level Values the get_level_values

# %%
bigmac = pd.read_csv("./pandasfiles/bigmac.csv",parse_dates=["Date"],index_col=['Date',"Country"])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.get_level_values("Date")
bigmac.index.get_level_values(0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values("Country")
bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %% [markdown]
# ### Change index Level Name with the set_names Method

# %%
bigmac.head(4)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67

# %%
bigmac.index.set_names(names=['Day','Location'])
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.index.set_names(names="Day",level="Date")
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %% [markdown]
# ### sort_index method on multi index

# %%
bigmac = pd.read_csv("./pandasfiles/bigmac.csv",parse_dates=["Date"],index_col=['Date',"Country"])

bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac.sort_index(ascending=False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(ascending=[True,False])
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83
#            UAE                           2.99
#            Turkey                        3.83
# ...                                       ...
# 2016-01-01 Brazil                        3.35
#            Belgium                       4.25
#            Austria                       3.76
#            Australia                     3.74
#            Argentina                     2.39
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(level='Date')
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.sort_index(level=1)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
# 2010-07-01 Argentina                 3.56
# 2011-07-01 Argentina                 4.84
# 2012-01-01 Argentina                 4.64
# 2012-07-01 Argentina                 4.16
# ...                                   ...
# 2014-01-01 Vietnam                   2.84
# 2014-07-01 Vietnam                   2.83
# 2015-01-01 Vietnam                   2.81
# 2015-07-01 Vietnam                   2.75
# 2016-01-01 Vietnam                   2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# ### Extract rows From a mutli index Data Frame

# %%
bigmac.sort_index(inplace=True)
bigmac.head(2)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98

# %%
bigmac.loc['2010-01-01',"Argentina"]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc['2010-01-01',"Price in US Dollars"]
# Out:
# Country
# Argentina         1.84
# Australia         3.98
# Brazil            4.76
# Britain           3.67
# Canada            3.97
# Chile             3.18
# China             1.83
# Colombia          3.91
# Costa Rica        3.52
# Czech Republic    3.71
# Denmark           5.99
# Egypt             2.38
# Euro area         4.84
# Hong Kong         1.91
# Hungary           3.86
# Indonesia         2.24
# Israel            3.99
# Japan             3.50
# Latvia            3.09
# Lithuania         2.87
# Malaysia          2.08
# Mexico            2.50
# New Zealand       3.61
# Norway            7.02
# Pakistan          2.42
# Peru              2.81
# Philippines       2.21
# Poland            2.86
# Russia            2.34
# Saudi Arabia      2.67
# Singapore         3.19
# South Africa      2.46
# South Korea       2.98
# Sri Lanka         1.83
# Sweden            5.51
# Switzerland       6.30
# Taiwan            2.36
# Thailand          2.11
# Turkey            3.83
# ...

# %%
bigmac.loc[("2010-01-01","Argentina"),]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc[("2010-01-01","Argentina"),"Price in US Dollars"]
# Out:
# 1.84

# %%
bigmac.iloc[0]
bigmac.iloc[10]
bigmac.iloc[[10,20,300]]
# Out:
#                         Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                     5.99
#            Malaysia                    2.08
# 2013-01-01 South Korea                 3.41

# %% [markdown]
# ### the transpose method

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac1 = bigmac.transpose()
bigmac1.head()
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac1.loc[("Price in US Dollars",),('2010-01-01','Sri Lanka'):('2010-01-01',"Ukaraine")]
# Out:
# Date                2010-01-01
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey   UAE
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83  2.99

# %% [markdown]
# ### The swaplevel method

# %%
bigmac.swaplevel()
bigmac.swaplevel("Date",'Country')
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %%
bigmac.swaplevel(1,0)
# Out:
#                           Price in US Dollars
# Country       Date
# Argentina     2010-01-01                 1.84
# Australia     2010-01-01                 3.98
# Brazil        2010-01-01                 4.76
# Britain       2010-01-01                 3.67
# Canada        2010-01-01                 3.97
# ...                                       ...
# Ukraine       2016-01-01                 1.54
# United States 2016-01-01                 4.93
# Uruguay       2016-01-01                 3.74
# Venezuela     2016-01-01                 0.66
# Vietnam       2016-01-01                 2.67
#
# [652 rows x 1 columns]

# %% [markdown]
# ### The .stack() Method

# %%
stats = pd.read_csv("./pandasfiles/worldstats.csv",
                   index_col=['country','year'])
stats
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12
# ...                      ...           ...
# Zimbabwe   1964    4279561.0  1.217138e+09
#            1963    4140804.0  1.159512e+09
#            1962    4006262.0  1.117602e+09
#            1961    3876638.0  1.096647e+09
#            1960    3752390.0  1.052990e+09
#
# [11211 rows x 2 columns]

# %%
stats.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %% [markdown]
# ### The .unstack()

# %%
s = stats.stack()

# %%
s.head()
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
# dtype: float64

# %%
s.unstack().unstack().unstack()
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %%
s = stats.stack()

# %%
s.head(3)
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
# dtype: float64

# %%
s.unstack(1)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population           NaN           NaN           NaN
#             GDP                  NaN           NaN           NaN
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP                  NaN           NaN           NaN
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %%
s.unstack(2)
# Out:
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
s.unstack(-3)
s.unstack(0)
# Out:
# country           Afghanistan       Albania       Algeria       Andorra  \
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
# ...                       ...           ...           ...           ...
# 2013 GDP         2.004633e+10  1.278103e+10  2.097035e+11  3.249101e+09
# 2014 Population  3.162751e+07  2.893654e+06  3.893433e+07           NaN
#      GDP         2.005019e+10  1.327796e+10  2.135185e+11           NaN
# 2015 Population  3.252656e+07  2.889167e+06  3.966652e+07           NaN
#      GDP         1.919944e+10  1.145560e+10  1.668386e+11           NaN
#
# country                Angola  Antigua and Barbuda    Arab World  \
# year
# ...

# %%
s.unstack(level=["country","year"])
# Out:
# country       Arab World                                            \
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
# country                                                             \
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
# country                                 ...      Zimbabwe                \
# year                2007          2006  ...          1969          1968
# Population  3.287666e+08  3.209067e+08  ...  5.036321e+06  4.874113e+06
# GDP         1.641666e+12  1.404190e+12  ...  1.747999e+09  1.479600e+09
#
# country                                                             \
# ...

# %%
s.unstack("year",fill_value=0)
# Out:
# year                            1960          1961          1962  \
# country
# Afghanistan Population  8.994793e+06  9.164945e+06  9.343772e+06
#             GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania     Population  0.000000e+00  0.000000e+00  0.000000e+00
#             GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Algeria     Population  1.112489e+07  1.140486e+07  1.169015e+07
# ...                              ...           ...           ...
# Yemen, Rep. GDP         0.000000e+00  0.000000e+00  0.000000e+00
# Zambia      Population  3.049586e+06  3.142848e+06  3.240664e+06
#             GDP         6.987397e+08  6.823597e+08  6.792797e+08
# Zimbabwe    Population  3.752390e+06  3.876638e+06  4.006262e+06
#             GDP         1.052990e+09  1.096647e+09  1.117602e+09
#
# year                            1963          1964          1965  \
# country
# Afghanistan Population  9.531555e+06  9.728645e+06  9.935358e+06
# ...

# %% [markdown]
# ### The pivot

# %%
sales = pd.read_csv("./pandasfiles/salesmen.csv",
                  parse_dates=['Date'])
sales['Salesman'] = sales['Salesman'].astype("category")
sales.head()
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982
# 3 2016-01-04      Bob     7917
# 4 2016-01-05      Bob     7837

# %%
sales.pivot(index="Date",columns="Salesman",values="Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %% [markdown]
# ### The pivot_table() Mehtod

# %%
foods = pd.read_csv("./pandasfiles/foods.csv")

# %%
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
foods.pivot_table(values="Spend",index="Gender",aggfunc="mean")
# Out:
#             Spend
# Gender
# Female  50.709629
# Male    49.397623

# %%
foods.pivot_table(values="Spend",index=['Gender',"Item"],aggfunc="mean")
# Out:
#                       Spend
# Gender Item
# Female Burger     49.930488
#        Burrito    50.092000
#        Chalupa    54.635000
#        Donut      49.926316
#        Ice Cream  49.788519
#        Sushi      50.355699
# Male   Burger     49.613919
#        Burrito    48.344819
#        Chalupa    49.186761
#        Donut      43.649565
#        Ice Cream  51.096000
#        Sushi      55.614384

# %%
foods.pivot_table(values="Spend",index=['Gender',"Item"],columns=['City','Frequency'],aggfunc="mean")
# Out:
# City               New York                                              \
# Frequency             Daily    Monthly      Never      Often       Once
# Gender Item
# Female Burger     43.778333  57.286667  97.890000  23.740000  52.425000
#        Burrito    44.890000  40.913333  47.432500  34.533333  59.940000
#        Chalupa    43.190000  79.185000  35.150000  39.730000  36.933333
#        Donut      39.841667  71.132500  56.070000  32.657500  29.065000
#        Ice Cream  65.547500  46.265000  68.716667  58.065000  35.616667
#        Sushi      40.535000  46.580000  69.330000  49.134286  32.358000
# Male   Burger     63.892000  62.430000  90.320000  27.735000  59.314000
#        Burrito    78.736667  49.180000  28.926667  47.480000  59.110000
#        Chalupa    27.045000  66.752000  39.818000  62.880000  23.340000
#        Donut      46.000000  45.932500  43.926000  46.600000  56.386667
#        Ice Cream  59.406667  50.733333  28.770000  69.510000  53.535000
# ...

# %%
foods.pivot_table(values="Spend",index=['Gender',"Item"],columns='City',aggfunc="count")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger           24            31        27
#        Burrito          23            28        34
#        Chalupa          19            32        25
#        Donut            31            30        34
#        Ice Cream        27            32        22
#        Sushi            31            30        32
# Male   Burger           22            21        31
#        Burrito          25            30        28
#        Chalupa          25            23        23
#        Donut            30            33        29
#        Ice Cream        29            41        25
#        Sushi            27            28        18

# %%
foods.pivot_table(values="Spend",index=['Gender',"Item"],columns='City',aggfunc="max")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger        98.96         97.79     85.06
#        Burrito       92.25         96.79     99.21
#        Chalupa       98.43         99.29     98.78
#        Donut         95.63         96.52     91.75
#        Ice Cream     97.83         88.14     97.44
#        Sushi         99.51         99.02     95.43
# Male   Burger        90.32         99.68     97.20
#        Burrito       98.04         93.27     95.07
#        Chalupa       96.44         98.40     99.87
#        Donut         86.70         93.12     99.26
#        Ice Cream     97.65         99.24     99.17
#        Sushi         93.85         97.12     98.48

# %%
pd.pivot_table(data=foods,values="Spend",index=['Gender',"Item"],columns='City',aggfunc="count")
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger           24            31        27
#        Burrito          23            28        34
#        Chalupa          19            32        25
#        Donut            31            30        34
#        Ice Cream        27            32        22
#        Sushi            31            30        32
# Male   Burger           22            21        31
#        Burrito          25            30        28
#        Chalupa          25            23        23
#        Donut            30            33        29
#        Ice Cream        29            41        25
#        Sushi            27            28        18

# %% [markdown]
# ### The pd.melt() method

# %%
sales = pd.read_csv("./pandasfiles/quarters.csv")
sales
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572
# 5      Ted  656644   70803  375948  321388
# 6      Jeb  486141  600753  742716  404995
# 7    Stacy  479662  742806  770712    2501
# 8   Morgan  992673  879183   37945  293710

# %%
pd.melt(sales,id_vars="Salesman",var_name="Quarter",value_name="Revenue")
# Out:
#    Salesman Quarter  Revenue
# 0     Boris      Q1   602908
# 1       Bob      Q1    43790
# 2     Tommy      Q1   392668
# 3    Travis      Q1   834663
# 4    Donald      Q1   580935
# 5       Ted      Q1   656644
# 6       Jeb      Q1   486141
# 7     Stacy      Q1   479662
# 8    Morgan      Q1   992673
# 9     Boris      Q2   233879
# 10      Bob      Q2   514863
# 11    Tommy      Q2   113579
# 12   Travis      Q2   266785
# 13   Donald      Q2   411379
# 14      Ted      Q2    70803
# 15      Jeb      Q2   600753
# 16    Stacy      Q2   742806
# 17   Morgan      Q2   879183
# 18    Boris      Q3   354479
# 19      Bob      Q3   297151
# 20    Tommy      Q3   430882
# 21   Travis      Q3   749238
# 22   Donald      Q3   110390
# 23      Ted      Q3   375948
# 24      Jeb      Q3   742716
# 25    Stacy      Q3   770712
# 26   Morgan      Q3    37945
# 27    Boris      Q4    32704
# 28      Bob      Q4   544493
# 29    Tommy      Q4   247231
# 30   Travis      Q4   570524
# ...
